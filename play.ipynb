# %%
from shared_libs.eec_parse import parse_markdown_yaml_metadata

# parse_markdown_yaml_metadata("EEC.md")
parse_markdown_yaml_metadata("EQNet/EEC.md")['extra_sys_path']
# Out:
# ['EQNet',
#  'shared_libs/3rd_party',
#  'shared_libs/3rd_party/qcnet_55cacb4',
#  'shared_libs/3rd_party/fairscale_3e6616',
#  'shared_libs/3rd_party/pytorch-image-models_2696ee',
#  'shared_libs/3rd_party/torchscale_4d1e0e']

# %%
from shared_libs.eec_parse import check_git_status_and_get_branch
from lightning.pytorch.loggers import TensorBoardLogger

BRANCH = check_git_status_and_get_branch()
tblogger = TensorBoardLogger(save_dir="results", name=BRANCH)
tblogger.log_dir
